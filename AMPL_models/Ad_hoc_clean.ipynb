# %% [markdown]
# ## Extra Cleaning Notebook for the MMP data
# MMP Data from https://tripod.nih.gov/tox21/challenge/data.jsp

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from rdkit import Chem

# %%
meas="MMP"
dir="up"
raw_df = pd.read_csv(f'../datasets/training_data/MMP_tox21_cur_with_moe_descriptors.csv')

raw_df
# Out:
#           compound_id                                  base_rdkit_smiles  \
# 0     NCGC00357083-01                          CCOC(OCC)C(=O)C1=CC=CC=C1
# 1     NCGC00255406-01                                   CCCC\C=C\C=C/C=O
# 2     NCGC00261426-01          FC1=CC=CC=C1C1=CC(=O)C2=CC3=C(OCO3)C=C2N1
# 3     NCGC00181170-01         CN1C(CCCC(O)=O)=NC2=C1C=CC(=C2)N(CCCl)CCCl
# 4     NCGC00014017-01                                      OC(=O)C1CCCN1
# ...               ...                                                ...
# 8773  NCGC00257413-01                         CCCCCCCCCCCCC1=C(O)C=CC=C1
# 8774          SPID484                  CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 8775  NCGC00258249-01               F[B-](F)(F)F.CCCCCCCCN1C=C[N+](C)=C1
# 8776  NCGC00095043-01                         OC1=C(O)C(=O)C(O)=C(O)C1=O
# 8777  NCGC00357123-01  [Na+].[Na+].[Na+].[Na+].[O-]S(=O)(=O)C1=CC(=C2...
#
#       active  ASA+_per_atom        ASA-  ASA_H_per_atom       ASA_P  \
# ...

# %%
clean = pd.read_csv(f'../datasets/training_data/MMP_tox21_cur.csv')
clean
# Out:
#           compound_id                   base_rdkit_smiles  active
# 0     NCGC00257743-01                           BrC(Br)Br     0.0
# 1     NCGC00258125-01                  BrC(Br)C(Br)(Br)Br     0.0
# 2     NCGC00257918-01                      BrC(Br)C(Br)Br     0.0
# 3     NCGC00260276-01                         BrC/C=C/CBr     0.0
# 4     NCGC00257050-01  BrC1CCC(Br)C(Br)CCC(Br)C(Br)CCC1Br     1.0
# ...               ...                                 ...     ...
# 6766  NCGC00256860-01                   c1coc(Cn2cccc2)c1     0.0
# 6767  NCGC00160467-01         c1csc(C2(N3CCCCC3)CCCCC2)c1     0.0
# 6768  NCGC00256662-01                  c1csc(SSc2cccs2)c1     0.0
# 6769  NCGC00257608-01                          c1nc[n-]n1     0.0
# 6770  NCGC00254087-01                          c1nc[nH]n1     0.0
#
# [6771 rows x 3 columns]

# %%
dupes = raw_df[raw_df["compound_id"].isin(clean["compound_id"])]
dupes.to_csv(f'../datasets/training_data/MMP_tox21_curMoe.csv', index=False)
